# %%
import pandas as pd
df=pd.read_csv('penguins_cleaned.csv')
df
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7                181
# 1       Adelie  Torgersen            39.5           17.4                186
# 2       Adelie  Torgersen            40.3           18.0                195
# 3       Adelie  Torgersen            36.7           19.3                193
# 4       Adelie  Torgersen            39.3           20.6                190
# ..         ...        ...             ...            ...                ...
# 328  Chinstrap      Dream            55.8           19.8                207
# 329  Chinstrap      Dream            43.5           18.1                202
# 330  Chinstrap      Dream            49.6           18.2                193
# 331  Chinstrap      Dream            50.8           19.0                210
# 332  Chinstrap      Dream            50.2           18.7                198
#
#      body_mass_g     sex
# 0           3750    male
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

# %%
x = pd.get_dummies(
    df[['species','island','bill_length_mm','bill_depth_mm',
        'flipper_length_mm','body_mass_g']],
    columns=['species','island'], drop_first=True
)
y = df['sex']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42,stratify=y)
scalar=StandardScaler()
model=LogisticRegression(penalty=None)
#model.fit(x_train,y_train)
#y_lr_pred=model.predict(x_test)
x_train=scalar.fit_transform(x_train)
x_test=scalar.transform(x_test)

model.fit(x_train,y_train)
y_pred = model.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
acc_train=accuracy_score(y_train, model.predict(x_train))
print("Vanilla Logistic Regression")
print("Accuracy(train):", acc_train)
print("Accuracy(test):", accuracy)


# Classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Vanilla Logistic Regression
# Accuracy(train): 0.9285714285714286
# Accuracy(test): 0.8805970149253731
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.90      0.85      0.88        33
#         male       0.86      0.91      0.89        34
#
#     accuracy                           0.88        67
#    macro avg       0.88      0.88      0.88        67
# weighted avg       0.88      0.88      0.88        67

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
import pandas as pd
# Import drive

# Mount Google Drive to ensure file access


# Re-define df to ensure it's available in this cell, using the path from M7X4XPYMWRIy
df = pd.read_csv('penguins_cleaned.csv')

# 1. Two features only, so the boundary is drawable.
# Correct column names to match the loaded DataFrame
fx, fy = 'species', 'island'
X2 = df[[fx, fy]].values
# Correct target column name to 'variety'
y_codes, classes = pd.factorize(df['sex'])     # 'Setosa'.. -> 0/1/2

# 2. A SEPARATE 2-feature model. NOT your 4-feature model.
viz = LogisticRegression(penalty=None, max_iter=1000)
viz.fit(X2, y_codes)          # unscaled on purpose — see note below

# 3. Grid over the feature space, predict class at every point.
x_min, x_max = X2[:,0].min()-0.5, X2[:,0].max()+0.5
y_min, y_max = X2[:,1].min()-0.5, X2[:,1].max()+0.5
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.02),
                     np.arange(y_min, y_max, 0.02))
Z = viz.predict(np.c_[xx.ravel(), yy.ravel()]).reshape(xx.shape)

# 4. Colored regions = model's decision; dots = real flowers.
plt.figure(figsize=(8,6))
plt.contourf(xx, yy, Z, alpha=0.3, cmap='viridis')
sc = plt.scatter(X2[:,0], X2[:,1], c=y_codes, cmap='viridis',
                 edgecolor='k', s=40)
plt.xlabel(fx); plt.ylabel(fy)
plt.title('Logistic Regression boundaries (2-feature version)')
plt.legend(handles=sc.legend_elements()[0], labels=list(classes))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 22
#      20 # 2. A SEPARATE 2-feature model. NOT your 4-feature model.
#      21 viz = LogisticRegression(penalty=None, max_iter=1000)
# ---> 22 viz.fit(X2, y_codes)          # unscaled on purpose — see note below
#      24 # 3. Grid over the feature space, predict class at every point.
#      25 x_min, x_max = X2[:,0].min()-0.5, X2[:,0].max()+0.5
#
# File /opt/anaconda3/lib/python3.13/site-packages/sklearn/base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# ...
